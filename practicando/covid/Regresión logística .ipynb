# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from math import sqrt
import seaborn as sns

# %%
# cargamos nuestro dataset
data_f = pd.read_csv('datasets/fallecidos_covid.csv', engine = 'python', sep=';')

# %%
data_c = pd.read_csv('datasets/positivos_covid.csv', sep=';')

# %%
data_f.head()
# Out:
#    FECHA_CORTE                              UUID  FECHA_FALLECIMIENTO  \
# 0     20210302  cdbdc47c6c955a031f997677becb9065             20200729
# 1     20210302  a3aaeeedaba295f128635f5edbda6498             20200729
# 2     20210302  631e87aac1be2aabd19935a6a255a569             20200729
# 3     20210302  74c292a1a2c357a786b26a13fc839719             20200729
# 4     20210302  229e060d0ece75f752a790eab2e4470d             20200729
#
#    EDAD_DECLARADA       SEXO   FECHA_NAC DEPARTAMENTO PROVINCIA    DISTRITO
# 0              64  MASCULINO  19551202.0         LIMA      LIMA  CHORRILLOS
# 1              78   FEMENINO  19420118.0         LIMA      LIMA       COMAS
# 2              66  MASCULINO  19540503.0         LIMA      LIMA       COMAS
# 3              69  MASCULINO  19510314.0         LIMA      LIMA       COMAS
# 4              71  MASCULINO  19490215.0         LIMA      LIMA       COMAS

# %%
data_c.head()
# Out:
#    FECHA_CORTE                              UUID DEPARTAMENTO    PROVINCIA  \
# 0     20210302  7320cabdc1aaca6c59014cae76a134e6  LIMA REGION   HUAROCHIRI
# 1     20210302  e81602051997ace8340bb8c18fe24c65     APURIMAC      ABANCAY
# 2     20210302  71ecb6bccb248b0bb2ac72ed51b5e979     APURIMAC      ABANCAY
# 3     20210302  566af4276cbe9359abe93f9aa86396c3     APURIMAC  ANDAHUAYLAS
# 4     20210302  027561e9d126e7c283d79c02cede562d     APURIMAC      ABANCAY
#
#       DISTRITO METODODX  EDAD      SEXO  FECHA_RESULTADO
# 0  SAN ANTONIO       PR  41.0  FEMENINO       20200526.0
# 1      ABANCAY       PR  32.0  FEMENINO       20200425.0
# 2      ABANCAY       PR  34.0  FEMENINO       20200429.0
# 3  ANDAHUAYLAS       PR  40.0  FEMENINO       20200426.0
# 4      ABANCAY       PR  40.0  FEMENINO       20200428.0

# %%
data_f.isnull()
sns.heatmap(data_f.isnull())
# Out:
# <AxesSubplot:>

# %%
data_f.drop(['FECHA_NAC','FECHA_CORTE'], axis=1,inplace=True)
data_f.isnull()
sns.heatmap(data_f.isnull())
# Out:
# <AxesSubplot:>

# %%
data_c.isnull()
sns.heatmap(data_c.isnull())
# Out:
# <AxesSubplot:>
